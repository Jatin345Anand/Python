# %%
import PyPDF2
import numpy as np
import pandas as pd
from PyPDF2 import PdfFileReader, PdfFileWriter
Path1stSemPDf = '/Users/jatinanand/Desktop/IPUPDFS/ALL2015BTechBatch/8sem2014batch.pdf'
# Input path your pdf....
def FindAllRawTextfromPDF(PdfPath):
    A=''
    pdf= PyPDF2.PdfFileReader(open(PdfPath, "rb"))
    for page in pdf.pages:
        A += page.extractText()
    return A
    
D1=FindAllRawTextfromPDF(Path1stSemPDf).split("\n")

EnrollmentNumbers=[]
EnrollmentNumbersIndexes=[]
for i in range(len(D1)):
    if(len(D1[i])==11):
        if(D1[i].isdigit()):
#             print(D1[i])
            EnrollmentNumbersIndexes.append(i)
            EnrollmentNumbers.append(D1[i])
def CollectFirstSemesterSubjestData(D):
    Ans=[]
    i1=0
    i2=EnrollmentNumbersIndexes[0]
#     print(i1,i2)
    while(i1<i2):
        Ans.append(D[i1])
        i1 += 1
    return Ans

def FindSemesterNumberformFirstRow(L):
    SemNumber=0
    for i in range(len(L)):
        if(L[i].find('SEMESTER')>-1):
            L2=L[i].split(" ")
            if(len(L2)>1):
#                 print(L2)
                for o in range(len(L2)):
                    if(L2[o].find('SEMESTER')>-1):
                        if(o>0):
#                             print(L2[o],o)
                            SemNumber=L2[o-1]
                            break
        if(L[i].find('Sem./Year:')>-1):
            L3=L[i].split(" ")
            if(len(L3)>1 and (i<len(L3)-1)):
#                 print(L3)
                for e in range(len(L3)):
                    if(L3[e].find('Sem./Year:')>-1):
                        if(e>0):
#                             print(L3[e],e)
                            SemNumber=L3[e+1]
                            break
    return SemNumber
                            
Lfirst=CollectFirstSemesterSubjestData(D1)
ALLLforALLSubjectID=[]
ALLLforALLSubjectID.append(Lfirst)
SemsL=[]
FirstStudentRowSemesterNumber=FindSemesterNumberformFirstRow(Lfirst)
SemsL.append(FirstStudentRowSemesterNumber)
def fetchRaw(i1,i2):
    L=[]
    while(i1<i2):
        L.append(D1[i1])
        i1 +=1
    return L
 
LL=[]
for i in range(len(EnrollmentNumbersIndexes)-1):
    LL.append(fetchRaw(EnrollmentNumbersIndexes[i],EnrollmentNumbersIndexes[i+1]))
LastIndexforLastEnroll=len(D1)-1
FirstIndexforLastEnroll=EnrollmentNumbersIndexes[len(EnrollmentNumbersIndexes)-1]
LastStudentList=[]
while(FirstIndexforLastEnroll<LastIndexforLastEnroll):
    LastStudentList.append(D1[FirstIndexforLastEnroll])
    FirstIndexforLastEnroll += 1
LL.append(LastStudentList)
# len(ALLLforALLSubjectID) 
def FindALLHigherList(L):
    Ans=[]
    for i in range(len(L)):
        if(len(L[i])>200):
            Ans.append(L[i])
    return Ans
def FindALLHigherListIndexes(L):
    Ans=[]
    for i in range(len(L)):
        if(len(L[i])>200):
            Ans.append(i)
    return Ans
LLLL= FindALLHigherList(LL)
for i in range(len(LLLL)):
     ALLLforALLSubjectID.append(LLLL[i])
NSemIndex=[]
for i in range(len(ALLLforALLSubjectID)):
    NSemIndex.append(FindSemesterNumberformFirstRow(ALLLforALLSubjectID[i]))

def FindALLPeperID(L):
    pid=[]
    pcode=[]
    pname=[]
    Ans=[]
    tp=[]
    for i in range(len(L)):
        if(len(L[i])==5 or len(L[i])==6):
            if(L[i].isdigit()):
                L1=[]
                pid.append(L[i])
                pcode.append(L[i+1])
                L1.append(L[i])
                L1.append(L[i+1])
                if(len(L[i+3])>3):
                    pname.append(L[i+2]+L[i+3])
                    L1.append(L[i+2]+L[i+3])
                    L1.append(L[i+5])
                else:
                    pname.append(L[i+2])
                    L1.append(L[i+2])
                    L1.append(L[i+4])
                Ans.append(L1)
    return Ans,pid,pname,pcode
ALLSubjectCodeNameID=list()
for i in ALLLforALLSubjectID:
    ALLSubjectCodeNameID.append(FindALLPeperID(i)[0])
PIDSCODE=list()
for i in ALLSubjectCodeNameID:
    for j in i:
        PIDSCODE.append(j)
def CreateUniqueElementListforsubject(L):
    output1=[]
    for x in L:
        if x[1] not in output1:
            output1.append(x[1])
    return output1
output1= CreateUniqueElementListforsubject(PIDSCODE)
FinalListofCodeIDName =[]
def FindALLDetailsUsingCode(L,code):
    for i in L:
        if(code.find(i[1])>-1):
            return i
for i in output1:
    FinalListofCodeIDName.append(FindALLDetailsUsingCode(PIDSCODE,i))
import json
def CreateJSON(L,JsonRootDataName):
    a={}
    P={}
    for i in range(len(L)):
        P.update({L[i][0]:L[i][1:]})
    a.update({JsonRootDataName:P})
    return json.dumps(a)
CreateJSON(FinalListofCodeIDName,'subject')
# Out:
# '{"subject": {"27402": ["ETCS402", "MACHINE LEARNING", "THEORY"], "31402": ["ETIT402", "MOBILE COMPUTING", "THEORY"], "98402": ["ETHS402", "HUMAN VALUES AND PROFESSIONAL ETHICS - II", "THEORY"], "27404": ["ETCS404", "HUMAN COMPUTER INTERACTION", "THEORY"], "28406": ["ETEC406", "AD HOC AND SENSOR NETWORKS", "THEORY"], "27408": ["ETCS408", "MICRO ELECTRONICS", "THEORY"], "31410": ["ETIT410", "SOFT COMPUTING", "THEORY"], "27412": ["ETCS412", "OBJECT ORIENTED SOFTWARE ENGINEERING", "THEORY"], "27414": ["ETCS414", "COMPUTER VISION", "THEORY"], "30414": ["ETIC414", "VLSI DESIGN", "THEORY"], "27416": ["ETCS416", "SOFTWARE PROJECT MANAGEMENT", "THEORY"], "31416": ["ETIT416", "INFORMATION THEORY AND CODING", "THEORY"], "27418": ["ETCS418", "WEB INTELLIGENCE AND BIG DATA", "THEORY"], "31418": ["ETIT418", "DIGITAL IMAGE PROCESSING", "THEORY"], "27420": ["ETCS420", "SERVICE ORIENTED ARCHITECTURE", "THEORY"], "27422": ["ETCS422", "MULTIAGENT SYSTEMS", "THEORY"], "27424": ["ETCS424", "PRINCIPLES OF PROGRAMMING LANGUAGES", "THEORY"], "27426": ["ETCS426", "TELECOMMUNICATION NETWORKS", "THEORY"], "27428": ["ETCS428", "SELECTED TOPICS OF RECENT TRENDS IN COMPUTER SCIENCE AND ENGINEERING", "THEORY"], "31430": ["ETIT430", "DISTRIBUTED SYSTEMS", "THEORY"], "31452": ["ETIT452", "MOBILE COMPUTING LAB", "PRACTICAL"], "27454": ["ETCS454", "MACHINE LEARNING LAB", "PRACTICAL"], "27456": ["ETCS456", "LAB BASED ON ELECTIVE - I", "PRACTICAL"], "27458": ["ETCS458", "LAB BASED ON ELECTIVE - II", "PRACTICAL"], "27460": ["ETCS460", "MAJOR PROJECT", "PRACTICAL"]}}'
