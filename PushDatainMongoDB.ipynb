# %%
import pandas as pd 
Path ='/Users/jatinanand/InterViewAssignments/TableTenisEvaluationApp/NewMainXLSX/NewJANJuniorGirl.xlsx'
# Path ='/Users/jatinanand/InterViewAssignments/TableTenisEvaluationApp/NewMainXLSX/NewFEBJuniorGirl.xlsx'
# Path ='/Users/jatinanand/InterViewAssignments/TableTenisEvaluationApp/NewMainXLSX/NewDECJuniorGirl.xlsx'
DF=pd.read_excel(Path)
import xlrd
workBook = xlrd.open_workbook(Path)
sheet= workBook.sheet_by_index(0)
ROWS = sheet.nrows
COLUMNS =sheet.ncols

# %%
for r in range(1,COLUMNS):
    print(sheet.cell_value(0,r))
# Out:
# PreviousRank
# CurrentRank
# Name
# PlayerID
# Country/County
# Points
# InactivePerioud

# %%
LLforBSON=[]
for r in range(1,ROWS): 
    LLforBSON.append(sheet.row_values(r))

# %%
LLforBSON
# Out:
# [[0.0, 2.0, 1.0, 'Charlotte Bardsley', 163059.0, 'Staffordshire', 1488.0, 0.0],
#  [1.0, 1.0, 2.0, 'Denise Payet', 1344.0, 'Middlesex', 1474.0, 1.0],
#  [2.0, 3.0, 3.0, 'Jasmin Wong', 165375.0, 'Yorkshire', 1300.0, 0.0],
#  [3.0, 4.0, 4.0, 'Mollie Patterson', 446.0, 'Norfolk', 1257.0, 0.0],
#  [4.0, 5.0, 5.0, 'Darcie Proud', 90566.0, 'Lincolnshire', 1188.0, 0.0],
#  [5.0, 6.0, 6.0, 'Anna Hursey', 6482.0, 'Wales', 1175.0, 0.0],
#  [6.0, 7.0, 7.0, 'Annie Hedlund', 198701.0, 'Sweden', 1171.0, 2.0],
#  [7.0, 8.0, 8.0, 'Megan Gidney', 172935.0, 'Lancashire', 1158.0, 0.0],
#  [8.0, 10.0, 9.0, 'Beth Richards', 170063.0, 'Wales', 1106.0, 0.0],
#  [9.0, 9.0, 10.0, 'Gauri Duhan', 5655.0, 'Yorkshire', 1070.0, 0.0],
#  [10.0, 16.0, 11.0, 'Danielle Kelly', 80573.0, 'Wales', 1053.0, 0.0],
#  [11.0, 12.0, 12.0, 'Ruby Chan', 157565.0, 'Yorkshire', 1033.0, 0.0],
#  [12.0, 14.0, 13.0, 'Natalia Ianau', 167173.0, 'Middlesex', 1012.0, 0.0],
# ...

# %%
import pymongo
from pymongo import MongoClient
Client = pymongo.MongoClient('localhost',27017)
# Client = pymongo.MongoClient('mongodb://jatinanand345:jatin#123@ds357955.mlab.com:57955/evaluationsystemdb')
db =  Client.ttevaluationdb
players = db.nplayers
def CreateMonthsDetails(L):
    ans={}
    ans['previousrank']=int(L[1])
    ans['currentrank']=int(L[2])
    ans['points']=int(L[-2])
    ans['inactiveperiod']=int(L[-1])
    return ans
def CreateBSON(L,Mname):
    print('in create....')
    pdic={}
    pdic['name']=L[3]
    pdic['playerid']=int(L[4])
    pdic['county']=str(L[5])
    pMonthsDic={}
    pMonthsDic[Mname]=CreateMonthsDetails(L)
    pdic['months']=pMonthsDic
    print(pdic)
    players.insert_one(pdic)
    return '0'
def UpdateBSON(L,Mname,PLAYER):
    print('in update...',PLAYER)
    MonthDic=PLAYER['months']
    print(MonthDic)
    PeriousMonths = list(MonthDic.keys())
    isExistsMonth=0
    for i in PeriousMonths:
        if(i.find(Mname)>-1):
            isExistsMonth=1
            break
    if(isExistsMonth==0):
        print('New Months ',CreateMonthsDetails(L))
        MonthDic.update({Mname:CreateMonthsDetails(L)})
#     print('New Dic',MonthDic)
#     print(PLAYER)
    NewValues= {"$set":PLAYER}
    players.update_one({'name':L[3]},NewValues)
#     if(Mname.find())
    print('In mongo ',players.find_one({'name':L[3]}))
    return '0'
def CreatePlayerBson(L):
    query={'name':L[3]}
    NoneType = type(None)
    IsExistPlayer = players.find_one(query)
    Mname=''
    Mname = Path[Path.rfind('/')+4:-15].lower()
    if(type(IsExistPlayer)==NoneType):
        if(CreateBSON(L,Mname)=='0'):
            ans='done'
    else:
        if(UpdateBSON(L,Mname,IsExistPlayer)=='0'):
            ans='done'
    return 'done'

# %%
for i in LLforBSON:
    CreatePlayerBson(i)
# Out:
# in update... {'_id': ObjectId('5ca51255cd50a4a6f0e84ae6'), 'name': 'Charlotte Bardsley', 'playerid': 163059, 'county': 'Staffordshire', 'months': {'jan': {'previousrank': 2, 'currentrank': 1, 'points': 1488, 'inactiveperiod': 0}, 'feb': {'previousrank': 1, 'currentrank': 1, 'points': 1484, 'inactiveperiod': 0}, 'dec': {'previousrank': 2, 'currentrank': 2, 'points': 1462, 'inactiveperiod': 0}}}
# {'jan': {'previousrank': 2, 'currentrank': 1, 'points': 1488, 'inactiveperiod': 0}, 'feb': {'previousrank': 1, 'currentrank': 1, 'points': 1484, 'inactiveperiod': 0}, 'dec': {'previousrank': 2, 'currentrank': 2, 'points': 1462, 'inactiveperiod': 0}}
# ...
